# %% [markdown]
# ### Library import

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Read in data

# %%
games = pd.read_json('../data/output_steam_games.json', lines=True)
games.dropna(how='all', inplace=True) # Drop registers where data is all np.nan
games.head()
# Out:
#               publisher                                             genres
# 88310         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]  \
# 88311  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313              彼岸领域                        [Action, Adventure, Casual]
# 88314              None                                               None
#
#                       app_name                    title
# 88310      Lost Summoner Kitty      Lost Summoner Kitty  \
# 88311                Ironbound                Ironbound
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 88313                  弹炸人2222                  弹炸人2222
# 88314            Log Challenge                     None
#
#                                                      url release_date
# 88310  http://store.steampowered.com/app/761140/Lost_...   2018-01-04  \
# 88311  http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 88312  http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 88313     http://store.steampowered.com/app/767400/2222/   2017-12-07
# 88314  http://store.steampowered.com/app/773570/Log_C...         None
#
#                                                     tags
# 88310      [Strategy, Action, Indie, Casual, Simulation]  \
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...
# 88313                        [Action, Adventure, Casual]
# 88314                    [Action, Indie, Casual, Sports]
#
#                                              reviews_url
# 88310  http://steamcommunity.com/app/761140/reviews/?...  \
# 88311  http://steamcommunity.com/app/643980/reviews/?...
# 88312  http://steamcommunity.com/app/670290/reviews/?...
# 88313  http://steamcommunity.com/app/767400/reviews/?...
# 88314  http://steamcommunity.com/app/773570/reviews/?...
#
#                                                    specs         price
# 88310                                    [Single-player]          4.99  \
# 88311  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 88312  [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 88313                                    [Single-player]          0.99
# 88314  [Single-player, Full controller support, HTC V...          2.99
#
#        early_access        id         developer
# 88310           0.0  761140.0         Kotoshiro
# 88311           0.0  643980.0  Secret Level SRL
# 88312           0.0  670290.0      Poolians.com
# 88313           0.0  767400.0              彼岸领域
# 88314           0.0  773570.0              None

# %%
games.columns # I want to see all the columns to know what columns I will use
# Out:
# Index(['publisher', 'genres', 'app_name', 'title', 'url', 'release_date',
#        'tags', 'reviews_url', 'specs', 'price', 'early_access', 'id',
#        'developer'],
#       dtype='object')

# %%
games = games[[
'id',
#'title', 
'app_name', 
#'url', 
'publisher', 
'developer',
#'release_date',
#'price', 
#'reviews_url', 
'genres', 
'tags', 
'specs', 
#'early_access', 
]] #Keep columns and coment the columns that I won't use and know what I discard
games.rename(columns={
    'id':'game_id',
    'app_name':'title',
}, inplace=True) #Rename the columsn
games.head()
# Out:
#         game_id                    title         publisher         developer
# 88310  761140.0      Lost Summoner Kitty         Kotoshiro         Kotoshiro  \
# 88311  643980.0                Ironbound  Making Fun, Inc.  Secret Level SRL
# 88312  670290.0  Real Pool 3D - Poolians      Poolians.com      Poolians.com
# 88313  767400.0                  弹炸人2222              彼岸领域              彼岸领域
# 88314  773570.0            Log Challenge              None              None
#
#                                                   genres
# 88310      [Action, Casual, Indie, Simulation, Strategy]  \
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88314                                               None
#
#                                                     tags
# 88310      [Strategy, Action, Indie, Casual, Simulation]  \
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...
# 88313                        [Action, Adventure, Casual]
# 88314                    [Action, Indie, Casual, Sports]
#
#                                                    specs
# 88310                                    [Single-player]
# 88311  [Single-player, Multi-player, Online Multi-Pla...
# 88312  [Single-player, Multi-player, Online Multi-Pla...
# 88313                                    [Single-player]
# 88314  [Single-player, Full controller support, HTC V...

# %%
games.isna().sum() #View all the np.nan in each columns
# Out:
# game_id         2
# title           2
# publisher    8052
# developer    3299
# genres       3283
# tags          163
# specs         670
# dtype: int64

# %%
games.shape
# Out:
# (32135, 7)

# %%
games.dropna(subset='game_id', inplace=True)
games.replace(np.nan, '', inplace=True)

# %% [markdown]
# ## Data flattening

# %%
games['genres'] = games['genres'].apply(lambda x: ' '.join(x) if isinstance(x, list) else ' ')
games['tags'] = games['tags'].apply(lambda x: ' '.join(x) if isinstance(x, list) else ' ')
games['specs'] = games['specs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else ' ')

# %%
games.head()
# Out:
#         game_id                    title         publisher         developer
# 88310  761140.0      Lost Summoner Kitty         Kotoshiro         Kotoshiro  \
# 88311  643980.0                Ironbound  Making Fun, Inc.  Secret Level SRL
# 88312  670290.0  Real Pool 3D - Poolians      Poolians.com      Poolians.com
# 88313  767400.0                  弹炸人2222              彼岸领域              彼岸领域
# 88314  773570.0            Log Challenge
#
#                                             genres
# 88310      Action Casual Indie Simulation Strategy  \
# 88311              Free to Play Indie RPG Strategy
# 88312  Casual Free to Play Indie Simulation Sports
# 88313                      Action Adventure Casual
# 88314
#
#                                                     tags
# 88310            Strategy Action Indie Casual Simulation  \
# 88311  Free to Play Strategy Indie RPG Card Game Trad...
# 88312  Free to Play Simulation Sports Casual Indie Mu...
# 88313                            Action Adventure Casual
# 88314                         Action Indie Casual Sports
#
#                                                    specs
# 88310                                      Single-player
# 88311  Single-player Multi-player Online Multi-Player...
# 88312  Single-player Multi-player Online Multi-Player...
# 88313                                      Single-player
# 88314  Single-player Full controller support HTC Vive...

# %%
games['game_id'] = games['game_id'].astype('int64') #Changing the data type
games['data'] = games['title'] + ' ' + games['publisher'] + ' ' + games['developer'] + ' ' + games['genres'] + ' ' + games['tags'] + ' ' + games['specs']
games.set_index('game_id').to_csv('../data/csv/games_to_recommend.csv')
games.head()
# Out:
#        game_id                    title         publisher         developer
# 88310   761140      Lost Summoner Kitty         Kotoshiro         Kotoshiro  \
# 88311   643980                Ironbound  Making Fun, Inc.  Secret Level SRL
# 88312   670290  Real Pool 3D - Poolians      Poolians.com      Poolians.com
# 88313   767400                  弹炸人2222              彼岸领域              彼岸领域
# 88314   773570            Log Challenge
#
#                                             genres
# 88310      Action Casual Indie Simulation Strategy  \
# 88311              Free to Play Indie RPG Strategy
# 88312  Casual Free to Play Indie Simulation Sports
# 88313                      Action Adventure Casual
# 88314
#
#                                                     tags
# 88310            Strategy Action Indie Casual Simulation  \
# 88311  Free to Play Strategy Indie RPG Card Game Trad...
# 88312  Free to Play Simulation Sports Casual Indie Mu...
# 88313                            Action Adventure Casual
# 88314                         Action Indie Casual Sports
#
#                                                    specs
# 88310                                      Single-player  \
# 88311  Single-player Multi-player Online Multi-Player...
# 88312  Single-player Multi-player Online Multi-Player...
# 88313                                      Single-player
# 88314  Single-player Full controller support HTC Vive...
#
#                                                     data
# 88310  Lost Summoner Kitty Kotoshiro Kotoshiro Action...
# 88311  Ironbound Making Fun, Inc. Secret Level SRL Fr...
# 88312  Real Pool 3D - Poolians Poolians.com Poolians....
# 88313  弹炸人2222 彼岸领域 彼岸领域 Action Adventure Casual Acti...
# 88314  Log Challenge     Action Indie Casual Sports S...

# %%
games = pd.read_csv('../data/csv/games_to_recommend.csv')
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(games['data'])
def Recommendation(title):
    title = title.lower()
    game_index = games[games['title'].str.lower() == title].index.values
    if len(game_index) > 0:
        similarity_scores = cosine_similarity(
            tfidf_matrix[game_index],
            tfidf_matrix
        )
        similar_games_index = similarity_scores.argsort()[0][-6:][::-1]
        similar_games = games.iloc[similar_games_index]
        game_index = similar_games[similar_games['title'].str.lower() == title ].index.values
        if len(game_index) > 0:
            similar_games.drop(index=game_index, inplace=True)
        else:
            similar_games.drop(similar_games.index[-1], inplace=True)

        return list(similar_games['game_id'])
    return 'Game not found'

# %%
Recommendation('Half-Life')
# Out:
# C:\Users\Lucas Augusto\AppData\Local\Temp\ipykernel_5312\1597164607.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   similar_games.drop(index=game_index, inplace=True)
# [280, 50, 220, 323130, 360]

# %%
from scipy.sparse import save_npz, load_npz
save_npz('../data/matrix/tfidf_matrix.npz', tfidf_matrix)

# %%
loaded_tfidf_matrix = load_npz('../data/matrix/tfidf_matrix.npz')
loaded_tfidf_matrix
